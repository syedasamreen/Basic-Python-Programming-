# %%
import pandas as pd

# %%
data = pd.read_csv(r'/home/syedasamreen/Documents/Time series practice and ML/energydata_complete.csv',parse_dates=True, na_values='Nan')
print(data)
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
data.tail()
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3    T4  ...    T9     RH_9  \
# 19730  25.890000  42.025714  27.200000  41.163333  24.7  ...  23.2  46.7900
# 19731  25.754000  42.080000  27.133333  41.223333  24.7  ...  23.2  46.7900
# 19732  25.628571  42.768571  27.050000  41.690000  24.7  ...  23.2  46.7900
# 19733  25.414000  43.036000  26.890000  41.290000  24.7  ...  23.2  46.8175
# 19734  25.264286  42.971429  26.823333  41.156667  24.7  ...  23.2  46.8450
#
#            T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# ...

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
data.cov()
# Out:
#                Appliances      lights         T1       RH_1         T2  \
# Appliances   10511.353180  160.512176   9.130075  35.098858  26.996601
# lights         160.512176   62.979899  -0.299882   3.378017  -0.097836
# T1               9.130075   -0.299882   2.579447   1.048163   2.947379
# RH_1            35.098858    3.378017   1.048163  15.834819   2.354751
# T2              26.996601   -0.097836   2.947379   2.354751   4.809133
# RH_2           -25.229350    1.646713  -0.016399  12.916086  -1.478068
# T3              17.494803   -1.550543   2.875271   2.021513   3.234600
# RH_3            12.109644    3.387651  -0.149234  10.939354   0.867146
# T4               8.436711   -0.143620   2.877446   0.863160   3.414049
# RH_4             7.551202    3.959842   0.682332  15.208557   2.204571
# T5               3.736981   -1.152735   2.622620   1.510613   2.914777
# RH_5             6.432828   10.112130  -0.214189  10.887387   0.585544
# ...

# %%
data.corr()
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
data.count()
# Out:
# date           19735
# Appliances     19735
# lights         19735
# T1             19735
# RH_1           19735
# T2             19735
# RH_2           19735
# T3             19735
# RH_3           19735
# T4             19735
# RH_4           19735
# T5             19735
# RH_5           19735
# T6             19735
# RH_6           19735
# T7             19735
# RH_7           19735
# T8             19735
# RH_8           19735
# T9             19735
# RH_9           19735
# T_out          19735
# Press_mm_hg    19735
# RH_out         19735
# Windspeed      19735
# Visibility     19735
# Tdewpoint      19735
# rv1            19735
# rv2            19735
# dtype: int64

# %%
data.boxplot(figsize=(18,12))
# Out:
# <AxesSubplot:>

# %%
data.nunique()
# Out:
# date           19735
# Appliances        92
# lights             8
# T1               722
# RH_1            2547
# T2              1650
# RH_2            3376
# T3              1426
# RH_3            2618
# T4              1390
# RH_4            2987
# T5              2263
# RH_5            7571
# T6              4446
# RH_6            9709
# T7              1955
# RH_7            5891
# T8              2228
# RH_8            6649
# T9               924
# RH_9            3388
# T_out           1730
# Press_mm_hg     2189
# RH_out           566
# Windspeed        189
# Visibility       413
# Tdewpoint       1409
# rv1            19735
# rv2            19735
# dtype: int64

# %%
data1 = data.round(2)

# %%
data1.lights
# Out:
# 0        30
# 1        30
# 2        30
# 3        40
# 4        40
#          ..
# 19730     0
# 19731     0
# 19732    10
# 19733    10
# 19734    10
# Name: lights, Length: 19735, dtype: int64

# %%
data1.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %%
data1.plot(x = 'date',kind='line',subplots = True, figsize = (18,12))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)

# %%
data1.plot(x = 'date',kind='bar', figsize = (18,12))

# %%
data1.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
data1[['date','Appliances']]
# Out:
#                       date  Appliances
# 0      2016-01-11 17:00:00          60
# 1      2016-01-11 17:10:00          60
# 2      2016-01-11 17:20:00          50
# 3      2016-01-11 17:30:00          50
# 4      2016-01-11 17:40:00          60
# ...                    ...         ...
# 19730  2016-05-27 17:20:00         100
# 19731  2016-05-27 17:30:00          90
# 19732  2016-05-27 17:40:00         270
# 19733  2016-05-27 17:50:00         420
# 19734  2016-05-27 18:00:00         430
#
# [19735 rows x 2 columns]

# %%
# %pwd
# Out:
# '/home/syedasamreen'

# %%
df = pd.read_html("https://www.theguardian.com/football/datablog/2012/dec/24/world-best-footballers-top-100-list")

# %%
df[0]
# Out:
#                          No                    Name                Position  \
# 0                         1            Lionel Messi                 Forward
# 1                         2       Cristiano Ronaldo                 Forward
# 2                         3                    Xavi              Midfielder
# 3                         4          Andres Iniesta              Midfielder
# 4                         5      Zlatan Ibrahimovic                 Forward
# ..                      ...                     ...                     ...
# 96                       97            Marek Hamsik              Midfielder
# 97                       98           Javi Martinez     Defender/midfielder
# 98                       99            Diego Forlan                 Forward
# 99                      100                Paulinho              Midfielder
# 100  Source: Guardian Sport  Source: Guardian Sport  Source: Guardian Sport
#
# ...

# %%
import requests
res = requests.get("https://api.github.com/users")
res
# Out:
# <Response [200]>

# %%
df1 = res.json()
type(df1)
# Out:
# list

# %%
df2 = pd.DataFrame(df1)

# %%
df2
# Out:
#            login  id                   node_id  \
# 0        mojombo   1              MDQ6VXNlcjE=
# 1        defunkt   2              MDQ6VXNlcjI=
# 2        pjhyett   3              MDQ6VXNlcjM=
# 3         wycats   4              MDQ6VXNlcjQ=
# 4       ezmobius   5              MDQ6VXNlcjU=
# 5           ivey   6              MDQ6VXNlcjY=
# 6        evanphx   7              MDQ6VXNlcjc=
# 7        vanpelt  17              MDQ6VXNlcjE3
# 8   wayneeseguin  18              MDQ6VXNlcjE4
# 9        brynary  19              MDQ6VXNlcjE5
# 10    kevinclark  20              MDQ6VXNlcjIw
# 11  technoweenie  21              MDQ6VXNlcjIx
# 12   macournoyer  22              MDQ6VXNlcjIy
# 13         takeo  23              MDQ6VXNlcjIz
# 14         caged  25              MDQ6VXNlcjI1
# 15      topfunky  26              MDQ6VXNlcjI2
# 16  anotherjesse  27              MDQ6VXNlcjI3
# 17        roland  28              MDQ6VXNlcjI4
# 18         lukas  29              MDQ6VXNlcjI5
# ...

# %%
df2[['id','html_url']]
# Out:
#     id                         html_url
# 0    1       https://github.com/mojombo
# 1    2       https://github.com/defunkt
# 2    3       https://github.com/pjhyett
# 3    4        https://github.com/wycats
# 4    5      https://github.com/ezmobius
# 5    6          https://github.com/ivey
# 6    7       https://github.com/evanphx
# 7   17       https://github.com/vanpelt
# 8   18  https://github.com/wayneeseguin
# 9   19       https://github.com/brynary
# 10  20    https://github.com/kevinclark
# 11  21  https://github.com/technoweenie
# 12  22   https://github.com/macournoyer
# 13  23         https://github.com/takeo
# 14  25         https://github.com/caged
# 15  26      https://github.com/topfunky
# 16  27  https://github.com/anotherjesse
# 17  28        https://github.com/roland
# 18  29         https://github.com/lukas
# 19  30      https://github.com/fanvsfan
# 20  31         https://github.com/tomtt
# 21  32    https://github.com/railsjitsu
# ...

# %%
for i in df2.columns:
    print(i)
# Out:
# login
# id
# node_id
# avatar_url
# gravatar_id
# url
# html_url
# followers_url
# following_url
# gists_url
# starred_url
# subscriptions_url
# organizations_url
# repos_url
# events_url
# received_events_url
# type
# site_admin

# %%
file = pd.to_csv("Git_hub.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6511/3944402562.py in <module>
# ----> 1 file = pd.to_csv("Git_hub.csv")
#
# ~/.local/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
type(file)
# Out:
# NoneType

# %%
df = pd.read_html("https://www.theguardian.com/football/datablog/2012/dec/24/world-best-footballers-top-100-list")
df[0]
# Out:
#                          No                    Name                Position  \
# 0                         1            Lionel Messi                 Forward
# 1                         2       Cristiano Ronaldo                 Forward
# 2                         3                    Xavi              Midfielder
# 3                         4          Andres Iniesta              Midfielder
# 4                         5      Zlatan Ibrahimovic                 Forward
# ..                      ...                     ...                     ...
# 96                       97            Marek Hamsik              Midfielder
# 97                       98           Javi Martinez     Defender/midfielder
# 98                       99            Diego Forlan                 Forward
# 99                      100                Paulinho              Midfielder
# 100  Source: Guardian Sport  Source: Guardian Sport  Source: Guardian Sport
#
# ...

# %%
file_html = df[0].to_csv("footbal_player.csv")

# %%
file = pd.read_csv("footbal_player.csv")

# %%
file.dtypes
# Out:
# Unnamed: 0             int64
# No                    object
# Name                  object
# Position              object
# Club                  object
# Nationality           object
# Age at Dec 20 2012    object
# dtype: object

# %%
file.describe()
# Out:
#        Unnamed: 0
# count  101.000000
# mean    50.000000
# std     29.300171
# min      0.000000
# 25%     25.000000
# 50%     50.000000
# 75%     75.000000
# max    100.000000

# %%
file1 = file[file.dtypes[file.dtypes == 'object'].index]

# %%
file1.describe()
# Out:
#          No          Name    Position       Club Nationality  \
# count   101           101         101        101         101
# unique  101           101           7         36          31
# top       1  Lionel Messi  Midfielder  Barcelona       Spain
# freq      1             1          36         12          16
#
#        Age at Dec 20 2012
# count                 101
# unique                 17
# top                    25
# freq                   16

# %%
file[file.dtypes[file.dtypes == 'int'].index]
# Out:
#      Unnamed: 0
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 96           96
# 97           97
# 98           98
# 99           99
# 100         100
#
# [101 rows x 1 columns]

# %%
pf = file[['Nationality']]

# %%
pf
# Out:
#                 Nationality
# 0                 Argentina
# 1                  Portugal
# 2                     Spain
# 3                     Spain
# 4                    Sweden
# ..                      ...
# 96                 Slovakia
# 97                    Spain
# 98                  Uruguay
# 99                   Brazil
# 100  Source: Guardian Sport
#
# [101 rows x 1 columns]

# %%
pd.Categorical(file['Nationality'])
# Out:
# ['Argentina', 'Portugal', 'Spain', 'Spain', 'Sweden', ..., 'Slovakia', 'Spain', 'Uruguay', 'Brazil', 'Source: Guardian Sport']
# Length: 101
# Categories (31, object): ['Argentina', 'Armenia', 'Belgium', 'Brazil', ..., 'Sweden', 'Uruguay', 'Wales', 'Zambia']

# %%
file['Nationality'].nunique()
# Out:
# 31

# %%
file['Nationality'].isna() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# Name: Nationality, Length: 101, dtype: bool
